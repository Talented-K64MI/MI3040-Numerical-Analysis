# %%
import numpy as np
from sympy import *
import matplotlib.pyplot as plt
import math
from numpy import linspace

# %% [markdown]
# ##### 1 - Phương pháp chia đôi

# %%
import bisection
uu = bisection.bisection_oop(1, 5, 0.01, "x**2-2");
print(uu.Solve());
# Out:
# 1.4140625

# %% [markdown]
# ##### 1 - Phương pháp tiếp tuyến

# %%
from newton_ralphson import *
expr = "x^3 + x^2 - x + 1";
L = -3; R = -1; eps = 1e-12;
uu = newton_oop(L, R, eps, expr);
print(f"Nghiệm của phương trình {expr} trên khoảng [{L}, {R}] là: {uu.Solve()}");
# Out:
# PP Newton ko hội tụ được
# Nghiệm của phương trình x^3 + x^2 - x + 1 trên khoảng [-3, -1] là: nan
# Invalid input. The program will now exit

# %% [markdown]
# ##### 3 - Phương pháp viền quanh

# %%
import Bordering
a = np.loadtxt("test.txt",dtype='float', delimiter=' ')
if(Bordering.checkdet(a) <0):
    print("eo lam dc")
else:
    n = len(a)
    b = Bordering.bordering(a,n)
    print(b)
# Out:
# eo lam dc

# %% [markdown]
# ##### 5 - Phương pháp xấp xỉ liên tiếp Pica

# %%
import Pica
filename = "Part5/pica2.txt"

result = Pica.Pica(filename, M = 2.5, L = 1)
result1 = Pica.Pica(filename, M = 2.5, L = 1, length = 31, mode = 'test')

print(result[0].evalf(2))
print("Khoảng hội tụ:", result[1])
Pica.PlotBoth(result, result1)
# Out:
# Lặp lần  1  với max error =  0.0725242623166003
# Lặp lần  2  với max error =  0.00305741770748913
# Lặp lần  3  với max error =  9.38783687298717e-5
# 0.0042*t**10 - 0.021*t**8 + 0.083*t**6 - 0.25*t**4 + 0.5*t**2 + 1.0
# Khoảng hội tụ: (-0.4, 0.4)

# %% [markdown]
# ##### 5 - Phương pháp chuỗi lũy thừa

# %%
import PowerSeries
t = symbols('t')
test1 = "Part5/PowerSeries.txt"
R, array = PowerSeries.Polynomial(test1)
print("Radius of convergence = " ,str(R), ", Result:")
np.set_printoptions(precision=1)
print(np.array(array))

PowerSeries.Plot([1,2], -2 , 2, g = sin(3*t))
PowerSeries.Save((R,array),output,"w")
# Out:
# Radius of convergence =  8.0 , Result:
# [ 0.   3.   0.  -4.5  0.   2.   0.  -0.4 -0.   0.1]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-bb847e277485> in <module>
#       7 print(np.array(array))
#       8
# ----> 9 PowerSeries.Plot([1,2], -2 , 2, g = sin(3*t))
#      10 PowerSeries.Save((R,array),output,"w")
#
# c:\users\doman\appdata\local\programs\python\python38-32\lib\site-packages\sympy\core\expr.py in __float__(self)
#     325         if result.is_number and result.as_real_imag()[1]:
#     326             raise TypeError("can't convert complex to float")
# --> 327         raise TypeError("can't convert expression to float")
#     328
#     329     def __complex__(self):
#
# TypeError: can't convert expression to float

# %%
def Plot(result, start, end, g = None):
    f = 0
    power = 0
    for i in result:
        f += i * (t ** power)
        power += 1
    Plotf(f, (start, end))
    if g is not None:
        Plotf(g, (start, end))
    return f

Plot([1,2], -2 , 2, g = sin(3*t))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-22c7d04668f0> in <module>
#      10     return f
#      11
# ---> 12 Plot([1,2], -2 , 2, g = sin(3*t))
#
# c:\users\doman\appdata\local\programs\python\python38-32\lib\site-packages\sympy\core\expr.py in __float__(self)
#     325         if result.is_number and result.as_real_imag()[1]:
#     326             raise TypeError("can't convert complex to float")
# --> 327         raise TypeError("can't convert expression to float")
#     328
#     329     def __complex__(self):
#
# TypeError: can't convert expression to float
